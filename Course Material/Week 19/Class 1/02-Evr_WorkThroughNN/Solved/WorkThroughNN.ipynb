# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 15
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 542us/step - loss: 0.9515 - accuracy: 0.4120
# Epoch 2/100
# 24/24 [==============================] - 0s 448us/step - loss: 0.8791 - accuracy: 0.4933
# Epoch 3/100
# 24/24 [==============================] - 0s 541us/step - loss: 0.8123 - accuracy: 0.4933
# Epoch 4/100
# 24/24 [==============================] - 0s 548us/step - loss: 0.7497 - accuracy: 0.4933
# Epoch 5/100
# 24/24 [==============================] - 0s 469us/step - loss: 0.6922 - accuracy: 0.4933
# Epoch 6/100
# 24/24 [==============================] - 0s 436us/step - loss: 0.6405 - accuracy: 0.4933
# Epoch 7/100
# 24/24 [==============================] - 0s 408us/step - loss: 0.5938 - accuracy: 0.4933
# Epoch 8/100
# 24/24 [==============================] - 0s 426us/step - loss: 0.5520 - accuracy: 0.4933
# Epoch 9/100
# 24/24 [==============================] - 0s 405us/step - loss: 0.5151 - accuracy: 0.4933
# Epoch 10/100
# 24/24 [==============================] - 0s 389us/step - loss: 0.4821 - accuracy: 0.5213
# Epoch 11/100
# 24/24 [==============================] - 0s 389us/step - loss: 0.4526 - accuracy: 0.6067
# Epoch 12/100
# 24/24 [==============================] - 0s 389us/step - loss: 0.4261 - accuracy: 0.7600
# Epoch 13/100
# 24/24 [==============================] - 0s 394us/step - loss: 0.4021 - accuracy: 0.9267
# Epoch 14/100
# 24/24 [==============================] - 0s 378us/step - loss: 0.3805 - accuracy: 0.9827
# Epoch 15/100
# 24/24 [==============================] - 0s 390us/step - loss: 0.3607 - accuracy: 0.9907
# Epoch 16/100
# 24/24 [==============================] - 0s 428us/step - loss: 0.3425 - accuracy: 0.9947
# Epoch 17/100
# 24/24 [==============================] - 0s 421us/step - loss: 0.3261 - accuracy: 0.9947
# Epoch 18/100
# 24/24 [==============================] - 0s 437us/step - loss: 0.3114 - accuracy: 0.9947
# Epoch 19/100
# 24/24 [==============================] - 0s 451us/step - loss: 0.2992 - accuracy: 0.9973
# Epoch 20/100
# 24/24 [==============================] - 0s 435us/step - loss: 0.2893 - accuracy: 0.9973
# Epoch 21/100
# 24/24 [==============================] - 0s 470us/step - loss: 0.2812 - accuracy: 0.9987
# Epoch 22/100
# 24/24 [==============================] - 0s 411us/step - loss: 0.2739 - accuracy: 0.9987
# Epoch 23/100
# 24/24 [==============================] - 0s 388us/step - loss: 0.2672 - accuracy: 0.9987
# Epoch 24/100
# 24/24 [==============================] - 0s 395us/step - loss: 0.2610 - accuracy: 0.9987
# Epoch 25/100
# 24/24 [==============================] - 0s 392us/step - loss: 0.2551 - accuracy: 0.9987
# Epoch 26/100
# 24/24 [==============================] - 0s 423us/step - loss: 0.2495 - accuracy: 0.9987
# Epoch 27/100
# 24/24 [==============================] - 0s 397us/step - loss: 0.2441 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 388us/step - loss: 0.2389 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 383us/step - loss: 0.2339 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 401us/step - loss: 0.2291 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 415us/step - loss: 0.2244 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 395us/step - loss: 0.2199 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 408us/step - loss: 0.2156 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 426us/step - loss: 0.2114 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 505us/step - loss: 0.2073 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 499us/step - loss: 0.2033 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 582us/step - loss: 0.1995 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 427us/step - loss: 0.1957 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 406us/step - loss: 0.1920 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 400us/step - loss: 0.1885 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 448us/step - loss: 0.1850 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 448us/step - loss: 0.1816 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 427us/step - loss: 0.1783 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 401us/step - loss: 0.1751 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 520us/step - loss: 0.1720 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 419us/step - loss: 0.1689 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 415us/step - loss: 0.1660 - accuracy: 1.0000
# Epoch 48/100
# Epoch 77/100
# 24/24 [==============================] - 0s 419us/step - loss: 0.1021 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 391us/step - loss: 0.1006 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 394us/step - loss: 0.0991 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 392us/step - loss: 0.0977 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 377us/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 375us/step - loss: 0.0948 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 438us/step - loss: 0.0934 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 416us/step - loss: 0.0921 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 446us/step - loss: 0.0908 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 441us/step - loss: 0.0895 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 492us/step - loss: 0.0882 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 482us/step - loss: 0.0869 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 447us/step - loss: 0.0857 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 456us/step - loss: 0.0845 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 463us/step - loss: 0.0833 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 430us/step - loss: 0.0821 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 512us/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 469us/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 414us/step - loss: 0.0787 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 416us/step - loss: 0.0776 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 438us/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 427us/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 524us/step - loss: 0.0745 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 520us/step - loss: 0.0735 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0688 - accuracy: 1.0000
# Loss: 0.06884726136922836, Accuracy: 1.0
